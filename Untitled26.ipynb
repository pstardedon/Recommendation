# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
# %matplotlib inline

# %%
os.getcwd(
)
# Out:
# 'C:\\Users\\PRECIOUS'

# %%
os.chdir('C:\\Users\\PRECIOUS\\Desktop\\praedwin')

# %%
os.getcwd(
)
# Out:
# 'C:\\Users\\PRECIOUS\\Desktop\\praedwin'

# %%
data= pd.read_csv('we.csv')

# %%
data
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %%
data.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
sdata=data[['artist.inverted', 'track', 'time', 'date.entered',
       'x1st.week', 'x2nd.week', 'x3rd.week']]

# %%
sdata
# Out:
#          artist.inverted                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost  3:04
# 313          Smith, Will                            Freakin' It  3:58
# 314        Zombie Nation                          Kernkraft 400  3:30
# 315       Eastsidaz, The                               Got Beef  3:58
# 316               Fragma                         Toca's Miracle  3:22
#
#     date.entered  x1st.week  x2nd.week  x3rd.week
# 0     2000-09-23         78       63.0       49.0
# ...

# %%
sdata.columns=['artist', 'track', 'time', 'date.entered','wk1', 'wk2', 'wk3']

# %%
sdata
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost  3:04
# 313          Smith, Will                            Freakin' It  3:58
# 314        Zombie Nation                          Kernkraft 400  3:30
# 315       Eastsidaz, The                               Got Beef  3:58
# 316               Fragma                         Toca's Miracle  3:22
#
#     date.entered  wk1   wk2   wk3
# 0     2000-09-23   78  63.0  49.0
# 1     2000-02-12   15   8.0   6.0
# ...

# %%
smelt =sdata.melt(['artist', 'track', 'time', 'date.entered'],['wk1', 'wk2', 'wk3'],'wks','rate')

# %%
smelt
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#     date.entered  wks  rate
# 0     2000-09-23  wk1  78.0
# 1     2000-02-12  wk1  15.0
# 2     1999-10-23  wk1  71.0
# ...

# %%
smelt['w'] = smelt['wks'].apply(lambda x : int(x[2]))

# %%
smelt
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#     date.entered  wks  rate  w
# 0     2000-09-23  wk1  78.0  1
# 1     2000-02-12  wk1  15.0  1
# ...

# %%
smelt.drop(['wks'], axis=1, inplace=True)

# %% [markdown]
# smelt

# %%
smelt
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#     date.entered  rate  w
# 0     2000-09-23  78.0  1
# 1     2000-02-12  15.0  1
# 2     1999-10-23  71.0  1
# ...

# %%
smelt['date.entered'] = pd.to_datetime(smelt['date.entered'])

# %%
smelt
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#     date.entered  rate  w
# 0     2000-09-23  78.0  1
# 1     2000-02-12  15.0  1
# 2     1999-10-23  71.0  1
# ...

# %%
smelt['date.entered'][0] + pd.to_timedelta('7days')
# Out:
# Timestamp('2000-09-30 00:00:00')

# %%
smelt
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#     date.entered  rate  w
# 0     2000-09-23  78.0  1
# 1     2000-02-12  15.0  1
# 2     1999-10-23  71.0  1
# ...

# %%
smelt['date']=smelt['date.entered'][0]+pd.to_timedelta('0days')*(smelt['w'])

# %%
smelt
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#     date.entered  rate  w       date
# 0     2000-09-23  78.0  1 2000-09-23
# 1     2000-02-12  15.0  1 2000-09-23
# ...

# %%
smelt.drop(['date.entered'], axis = 1, inplace = True)

# %% [markdown]
# smelt

# %%
smelt
# Out:
#                   artist                                  track  time  rate  \
# 0        Destiny's Child               Independent Women Part I  3:38  78.0
# 1                Santana                           Maria, Maria  4:18  15.0
# 2          Savage Garden                     I Knew I Loved You  4:07  71.0
# 3                Madonna                                  Music  3:45  41.0
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  57.0
# ..                   ...                                    ...   ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04   NaN
# 947          Smith, Will                            Freakin' It  3:58  99.0
# 948        Zombie Nation                          Kernkraft 400  3:30   NaN
# 949       Eastsidaz, The                               Got Beef  3:58   NaN
# 950               Fragma                         Toca's Miracle  3:22   NaN
#
#      w       date
# 0    1 2000-09-23
# ...

# %%
newdata = smelt

# %%
newdata
# Out:
#                   artist                                  track  time  rate  \
# 0        Destiny's Child               Independent Women Part I  3:38  78.0
# 1                Santana                           Maria, Maria  4:18  15.0
# 2          Savage Garden                     I Knew I Loved You  4:07  71.0
# 3                Madonna                                  Music  3:45  41.0
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  57.0
# ..                   ...                                    ...   ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04   NaN
# 947          Smith, Will                            Freakin' It  3:58  99.0
# 948        Zombie Nation                          Kernkraft 400  3:30   NaN
# 949       Eastsidaz, The                               Got Beef  3:58   NaN
# 950               Fragma                         Toca's Miracle  3:22   NaN
#
#      w       date
# 0    1 2000-09-23
# ...

# %%
newdata.columns
# Out:
# Index(['artist', 'track', 'time', 'rate', 'w', 'date'], dtype='object')

# %%
newdata.sort_values(['artist', 'track', 'time', 'rate'], inplace=True)

# %%
newdata
# Out:
#               artist                                              track  time  \
# 880            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 563            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 604          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 287          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# ..               ...                                                ...   ...
# 631    Zombie Nation                                      Kernkraft 400  3:30
# 948    Zombie Nation                                      Kernkraft 400  3:30
# 649  matchbox twenty                                               Bent  4:12
# 332  matchbox twenty                                               Bent  4:12
# 15   matchbox twenty                                               Bent  4:12
#
#      rate  w       date
# ...

# %%
tracedata = newdata[['artist', 'track','time']]

# %%
tracedata
# Out:
#               artist                                              track  time
# 880            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 563            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 604          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 287          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# ..               ...                                                ...   ...
# 631    Zombie Nation                                      Kernkraft 400  3:30
# 948    Zombie Nation                                      Kernkraft 400  3:30
# 649  matchbox twenty                                               Bent  4:12
# 332  matchbox twenty                                               Bent  4:12
# 15   matchbox twenty                                               Bent  4:12
#
# [951 rows x 3 columns]

# %%
tracedata.drop_duplicates(['artist', 'track', 'time'], inplace = True)
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tracedata
# Out:
#                artist                                              track  time
# 880             2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 604           2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 658      3 Doors Down                                         Kryptonite  3:53
# 827      3 Doors Down                                              Loser  4:24
# 703          504 Boyz                                      Wobble Wobble  3:35
# ..                ...                                                ...   ...
# 888       Yankee Grey                               Another Nine Minutes  3:10
# 594  Yearwood, Trisha                                    Real Live Woman  3:55
# 885   Ying Yang Twins                            Whistle While You Twurk  4:19
# 314     Zombie Nation                                      Kernkraft 400  3:30
# 649   matchbox twenty                                               Bent  4:12
#
# [317 rows x 3 columns]

# %%
tracedata.head(20)
# Out:
#                   artist                                              track  \
# 880                2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 604              2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 658         3 Doors Down                                         Kryptonite
# 827         3 Doors Down                                              Loser
# 703             504 Boyz                                      Wobble Wobble
# 656                  98Ą                 Give Me Just One Night (Una Noche)
# 938              A*Teens                                      Dancing Queen
# 769              Aaliyah                                      I Don't Wanna
# 648              Aaliyah                                          Try Again
# 834       Adams, Yolanda                                      Open My Heart
# 861        Adkins, Trace                                               More
# ...
