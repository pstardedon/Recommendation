# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from PIL import Image
import os

# %%
path = 'logo.jpg'

# %%
pic = plt.imread(path)
plt.imshow(pic)
plt.show()

# %%
b = Image.open(path)
gray = b.convert("L")

# %%
gray
# Out:
# <PIL.Image.Image image mode=L size=536x564 at 0x423EF50>

# %%
doc = np.asarray(gray)

# %%
plt.imshow(doc, cmap = "gray")
plt.show()

# %%
a = b.resize((100,100))

# %%
a.show()

# %%
fpath = os.path.join("/Users/PRECIOUS/Desktop/"+"newlogo"+".png")
a.save(fpath)
