# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON'

# %%
path = "\\Users\\KENUKON\\Videos"

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Videos'

# %%
os.mkdir('assets')

# %%
os.chdir("\\Users\\KENUKON\\Videos\\assets")

# %%
os.listdir()
# Out:
# ['we.csv']

# %%
data = pd.read_csv('we.csv')

# %%
data
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %%
data.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
smallData = data[['artist.inverted', 'track', 'time', 'date.entered', 'x1st.week', 'x2nd.week', 'x3rd.week']]

# %%
smallData.columns = ['artist', 'track', 'time','date.entered', 'wk1', 'wk2', 'wk3']

# %%
smallData
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost  3:04
# 313          Smith, Will                            Freakin' It  3:58
# 314        Zombie Nation                          Kernkraft 400  3:30
# 315       Eastsidaz, The                               Got Beef  3:58
# 316               Fragma                         Toca's Miracle  3:22
#
#     date.entered  wk1   wk2   wk3
# 0     2000-09-23   78  63.0  49.0
# 1     2000-02-12   15   8.0   6.0
# ...

# %%
meltedData = smallData.melt(['artist', 'track', 'time','date.entered'],['wk1', 'wk2', 'wk3'], 'week', 'rate')

# %%
meltedData
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#     date.entered week  rate
# 0     2000-09-23  wk1  78.0
# 1     2000-02-12  wk1  15.0
# 2     1999-10-23  wk1  71.0
# ...

# %%
meltedData.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered week  rate
# 0   2000-09-23  wk1  78.0
# 1   2000-02-12  wk1  15.0
# 2   1999-10-23  wk1  71.0
# 3   2000-08-12  wk1  41.0
# 4   2000-08-05  wk1  57.0

# %%
meltedData['wk'] = meltedData['week'].str.slice(2)

# %%
meltedData['wk'] = meltedData['week'].apply(lambda x: int(x[2]))

# %%
meltedData.drop(['week'], axis = 1, inplace = True)

# %%
meltedData.columns = ['artist', 'track', 'time', 'date', 'rate', 'week']

# %%
meltedData
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#            date  rate  week
# 0    2000-09-23  78.0     1
# 1    2000-02-12  15.0     1
# 2    1999-10-23  71.0     1
# ...

# %%
meltedData['date'] = pd.to_datetime(meltedData['date'])

# %%
meltedData
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#           date  rate  week
# 0   2000-09-23  78.0     1
# 1   2000-02-12  15.0     1
# 2   1999-10-23  71.0     1
# ...

# %%
meltedData['date'][0] + pd.to_timedelta('7days')
# Out:
# Timestamp('2000-09-30 00:00:00')

# %%
meltedData['dt'] = meltedData['date'] + pd.to_timedelta('0day') * (meltedData['week'])

# %%
meltedData
# Out:
#                   artist                                  track  time  \
# 0        Destiny's Child               Independent Women Part I  3:38
# 1                Santana                           Maria, Maria  4:18
# 2          Savage Garden                     I Knew I Loved You  4:07
# 3                Madonna                                  Music  3:45
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..                   ...                                    ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04
# 947          Smith, Will                            Freakin' It  3:58
# 948        Zombie Nation                          Kernkraft 400  3:30
# 949       Eastsidaz, The                               Got Beef  3:58
# 950               Fragma                         Toca's Miracle  3:22
#
#           date  rate  week         dt
# 0   2000-09-23  78.0     1 2000-09-23
# 1   2000-02-12  15.0     1 2000-02-12
# ...

# %%
meltedData.drop(['date'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-368840e79e11> in <module>
# ----> 1 meltedData.drop(['date'], axis = 1, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
meltedData
# Out:
#                   artist                                  track  time  rate  \
# 0        Destiny's Child               Independent Women Part I  3:38  78.0
# 1                Santana                           Maria, Maria  4:18  15.0
# 2          Savage Garden                     I Knew I Loved You  4:07  71.0
# 3                Madonna                                  Music  3:45  41.0
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  57.0
# ..                   ...                                    ...   ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04   NaN
# 947          Smith, Will                            Freakin' It  3:58  99.0
# 948        Zombie Nation                          Kernkraft 400  3:30   NaN
# 949       Eastsidaz, The                               Got Beef  3:58   NaN
# 950               Fragma                         Toca's Miracle  3:22   NaN
#
#      week         dt
# 0       1 2000-09-23
# ...

# %%
meltedData.columns = ['artist', 'track', 'time', 'rate', 'week', 'date']

# %%
meltedData
# Out:
#                   artist                                  track  time  rate  \
# 0        Destiny's Child               Independent Women Part I  3:38  78.0
# 1                Santana                           Maria, Maria  4:18  15.0
# 2          Savage Garden                     I Knew I Loved You  4:07  71.0
# 3                Madonna                                  Music  3:45  41.0
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  57.0
# ..                   ...                                    ...   ...   ...
# 946     Ghostface Killah                       Cherchez LaGhost  3:04   NaN
# 947          Smith, Will                            Freakin' It  3:58  99.0
# 948        Zombie Nation                          Kernkraft 400  3:30   NaN
# 949       Eastsidaz, The                               Got Beef  3:58   NaN
# 950               Fragma                         Toca's Miracle  3:22   NaN
#
#      week       date
# 0       1 2000-09-23
# ...

# %%
newData = meltedData

# %%
newData.columns
# Out:
# Index(['artist', 'track', 'time', 'rate', 'week', 'date'], dtype='object')

# %%
newData.sort_values(['artist', 'track', 'time'], inplace = True)

# %%
trackData = newData[['artist', 'track', 'time']]

# %%
trackData
# Out:
#               artist                                              track  time
# 246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 563            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 880            2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 287          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 604          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# ..               ...                                                ...   ...
# 631    Zombie Nation                                      Kernkraft 400  3:30
# 948    Zombie Nation                                      Kernkraft 400  3:30
# 15   matchbox twenty                                               Bent  4:12
# 332  matchbox twenty                                               Bent  4:12
# 649  matchbox twenty                                               Bent  4:12
#
# [951 rows x 3 columns]

# %%
trackData.drop_duplicates(['artist', 'track', 'time'], inplace = True)
# Out:
# C:\Users\KENUKON\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
trackData
# Out:
#                artist                                              track  time
# 246             2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 287           2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 24       3 Doors Down                                         Kryptonite  3:53
# 193      3 Doors Down                                              Loser  4:24
# 69           504 Boyz                                      Wobble Wobble  3:35
# ..                ...                                                ...   ...
# 254       Yankee Grey                               Another Nine Minutes  3:10
# 277  Yearwood, Trisha                                    Real Live Woman  3:55
# 251   Ying Yang Twins                            Whistle While You Twurk  4:19
# 314     Zombie Nation                                      Kernkraft 400  3:30
# 15    matchbox twenty                                               Bent  4:12
#
# [317 rows x 3 columns]

# %%
trackData.index.name = 'id'

# %%
trackData
# Out:
#                artist                                              track  time
# id
# 246             2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 287           2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 24       3 Doors Down                                         Kryptonite  3:53
# 193      3 Doors Down                                              Loser  4:24
# 69           504 Boyz                                      Wobble Wobble  3:35
# ..                ...                                                ...   ...
# 254       Yankee Grey                               Another Nine Minutes  3:10
# 277  Yearwood, Trisha                                    Real Live Woman  3:55
# 251   Ying Yang Twins                            Whistle While You Twurk  4:19
# 314     Zombie Nation                                      Kernkraft 400  3:30
# 15    matchbox twenty                                               Bent  4:12
#
# ...

# %%
trackDataid = trackData.reset_index()
trackDataid
# Out:
#       id            artist                                              track  \
# 0    246             2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 1    287           2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 2     24      3 Doors Down                                         Kryptonite
# 3    193      3 Doors Down                                              Loser
# 4     69          504 Boyz                                      Wobble Wobble
# ..   ...               ...                                                ...
# 312  254       Yankee Grey                               Another Nine Minutes
# 313  277  Yearwood, Trisha                                    Real Live Woman
# 314  251   Ying Yang Twins                            Whistle While You Twurk
# 315  314     Zombie Nation                                      Kernkraft 400
# 316   15   matchbox twenty                                               Bent
#
#      time
# 0    4:22
# ...

# %%
pd.merge(trackDataid, newData, on = ['artist', 'track', 'time'])
# Out:
#       id           artist                                              track  \
# 0    246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 1    246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 2    246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 3    287          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 4    287          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# ..   ...              ...                                                ...
# 946  314    Zombie Nation                                      Kernkraft 400
# 947  314    Zombie Nation                                      Kernkraft 400
# 948   15  matchbox twenty                                               Bent
# 949   15  matchbox twenty                                               Bent
# 950   15  matchbox twenty                                               Bent
#
#      time  rate  week       date
# ...

# %%
cleanData = pd.merge(trackDataid, newData, on = ['artist', 'track', 'time'])

# %%
cleanData
# Out:
#       id           artist                                              track  \
# 0    246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 1    246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 2    246            2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 3    287          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 4    287          2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# ..   ...              ...                                                ...
# 946  314    Zombie Nation                                      Kernkraft 400
# 947  314    Zombie Nation                                      Kernkraft 400
# 948   15  matchbox twenty                                               Bent
# 949   15  matchbox twenty                                               Bent
# 950   15  matchbox twenty                                               Bent
#
#      time  rate  week       date
# ...

# %%
cleanData.drop_duplicates(['artist', 'track', 'time'], inplace = True)

# %%
cleanData
# Out:
#       id            artist                                              track  \
# 0    246             2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 3    287           2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 6     24      3 Doors Down                                         Kryptonite
# 9    193      3 Doors Down                                              Loser
# 12    69          504 Boyz                                      Wobble Wobble
# ..   ...               ...                                                ...
# 936  254       Yankee Grey                               Another Nine Minutes
# 939  277  Yearwood, Trisha                                    Real Live Woman
# 942  251   Ying Yang Twins                            Whistle While You Twurk
# 945  314     Zombie Nation                                      Kernkraft 400
# 948   15   matchbox twenty                                               Bent
#
#      time  rate  week       date
# ...

# %%
cleanData.tail(50)
# Out:
#       id               artist                               track  time  rate  \
# 801  313          Smith, Will                         Freakin' It  3:58  99.0
# 804  103          Son By Four       A Puro Dolor (Purest Of Pain)  3:30  80.0
# 807   50              Sonique                    It Feels So Good  3:48  67.0
# 810   85         SoulDecision                               Faded  3:25  94.0
# 813   63      Spears, Britney  From The Bottom Of My Broken Heart  4:30  76.0
# 816   93      Spears, Britney                               Lucky  3:23  61.0
# 819   51      Spears, Britney              Oops!.. I Did It Again  3:30  67.0
# 822  291      Spencer, Tracie                   Still In My Heart  4:11  95.0
# 825  215             Splender             I Think God Can Explain  3:55  71.0
# 828   70                Sting                         Desert Rose  3:52  98.0
# 831  272  Stone Temple Pilots                           Sour Girl  4:16  79.0
# ...

# %%
cleanData.loc[cleanData[cleanData.week == 1]['rate'].idxmax()]
# Out:
# id                        248
# artist                  Drama
# track       Left, Right, Left
# time                     3:37
# rate                      100
# week                        1
# date      2000-02-12 00:00:00
# Name: 258, dtype: object

# %%
cleanData.query('id == 248')
# Out:
#       id artist              track  time   rate  week       date
# 258  248  Drama  Left, Right, Left  3:37  100.0     1 2000-02-12

# %%
cleanData.to_csv("cleanData.csv", index = False)
