# %%
import numpy as np
import pandas as pd
import os

# %%
arr1 = np.array([[2,4,5,6,1],[7,3,9,np.nan,3],[3,np.nan,4,np.nan,np.nan],[np.nan,3,2,1,7]])
arr2 = np.array(['A','B','C','D'])
arr3 = np.array(['U','V','W','X','Y'])

# %%
dtf = pd.DataFrame(data = arr1, index = arr2, columns = arr3)
dtf
# Out:
#      U    V    W    X    Y
# A  2.0  4.0  5.0  6.0  1.0
# B  7.0  3.0  9.0  NaN  3.0
# C  3.0  NaN  4.0  NaN  NaN
# D  NaN  3.0  2.0  1.0  7.0

# %%
dtf2 = dtf*2

# %%
dtf2
# Out:
#       U    V     W     X     Y
# A   4.0  8.0  10.0  12.0   2.0
# B  14.0  6.0  18.0   NaN   6.0
# C   6.0  NaN   8.0   NaN   NaN
# D   NaN  6.0   4.0   2.0  14.0

# %%
dtf3 = dtf/100

# %%
con = pd.concat([dtf,dtf2,dtf3])

# %%
con
# Out:
#        U     V      W      X      Y
# A   2.00  4.00   5.00   6.00   1.00
# B   7.00  3.00   9.00    NaN   3.00
# C   3.00   NaN   4.00    NaN    NaN
# D    NaN  3.00   2.00   1.00   7.00
# A   4.00  8.00  10.00  12.00   2.00
# B  14.00  6.00  18.00    NaN   6.00
# C   6.00   NaN   8.00    NaN    NaN
# D    NaN  6.00   4.00   2.00  14.00
# A   0.02  0.04   0.05   0.06   0.01
# B   0.07  0.03   0.09    NaN   0.03
# C   0.03   NaN   0.04    NaN    NaN
# D    NaN  0.03   0.02   0.01   0.07

# %%
con.dropna(thresh = 2)
# Out:
#        U     V      W      X      Y
# A   2.00  4.00   5.00   6.00   1.00
# B   7.00  3.00   9.00    NaN   3.00
# C   3.00   NaN   4.00    NaN    NaN
# D    NaN  3.00   2.00   1.00   7.00
# A   4.00  8.00  10.00  12.00   2.00
# B  14.00  6.00  18.00    NaN   6.00
# C   6.00   NaN   8.00    NaN    NaN
# D    NaN  6.00   4.00   2.00  14.00
# A   0.02  0.04   0.05   0.06   0.01
# B   0.07  0.03   0.09    NaN   0.03
# C   0.03   NaN   0.04    NaN    NaN
# D    NaN  0.03   0.02   0.01   0.07

# %%
dtf
# Out:
#      U    V    W    X    Y
# A  2.0  4.0  5.0  6.0  1.0
# B  7.0  3.0  9.0  NaN  3.0
# C  3.0  NaN  4.0  NaN  NaN
# D  NaN  3.0  2.0  1.0  7.0

# %%
def square(x):
    b = lambda x:x*x
    y = b(x)
    return y

# %%
square(5)
# Out:
# 25

# %%
dtf['Z'] = dtf['X'].apply(square)

# %%
dtf
# Out:
#      U    V    W    X    Y     Z
# A  2.0  4.0  5.0  6.0  1.0  36.0
# B  7.0  3.0  9.0  NaN  3.0   NaN
# C  3.0  NaN  4.0  NaN  NaN   NaN
# D  NaN  3.0  2.0  1.0  7.0   1.0

# %%
dtf["V"].apply(lambda x:x*9)
# Out:
# A    36.0
# B    27.0
# C     NaN
# D    27.0
# Name: V, dtype: float64

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PRECIOUS'

# %%
data = pd.read_csv('nba.csv')

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#First Values
data.head(20)
# Out:
#                        Name            Team  Number Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1               Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2              John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3               R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4             Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 5              Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 6             Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 7              Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 8              Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 9              Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# ...

# %%
data.tail(20)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 438    Luis Montero  Portland Trail Blazers    44.0       SG  23.0    6-7
# 439   Mason Plumlee  Portland Trail Blazers    24.0        C  26.0   6-11
# 440   Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 441     Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 442   Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# 443      Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 444      Alec Burks               Utah Jazz    10.0       SG  24.0    6-6
# 445      Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 446  Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 447     Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 448  Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
# 449     Rodney Hood               Utah Jazz     5.0       SG  23.0    6-8
# ...

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
#Q1: Check out how many teams we have in this data
data['Team'].nunique()
# Out:
# 30

# %%
#Q2: Check out the Maximum Salary
data['Salary'].max()
# Out:
# 25000000.0

# %%
b = data.groupby('Team')

# %%
b.count()
# Out:
#                         Name  Number  Position  Age  Height  Weight  College  \
# Team
# Atlanta Hawks             15      15        15   15      15      15       11
# Boston Celtics            15      15        15   15      15      15       13
# Brooklyn Nets             15      15        15   15      15      15       13
# Charlotte Hornets         15      15        15   15      15      15       13
# Chicago Bulls             15      15        15   15      15      15       12
# Cleveland Cavaliers       15      15        15   15      15      15       12
# Dallas Mavericks          15      15        15   15      15      15       12
# Denver Nuggets            15      15        15   15      15      15        9
# Detroit Pistons           15      15        15   15      15      15       15
# Golden State Warriors     15      15        15   15      15      15       12
# Houston Rockets           15      15        15   15      15      15       11
# ...

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
b = data.dropna(subset=['College'])
