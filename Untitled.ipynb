# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import os

# %%
# a = []
# for pic in glob.glob("*.png"):
#     a.append(pic)
#     print(pic)

# for items in a:
#     b = plt.imread(items)
#     plt.imshow(b)
#     plt.show()

# %%
c = []
io = []
ir = []

for pict in glob.glob("*.png"):
    newp = Image.open(pict)
    io.append(newp)
    print(pict)
# Out:
# done.png
# manu.png
# mcity.png

# %%
io
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=P size=512x512 at 0x6084D30>,
#  <PIL.PngImagePlugin.PngImageFile image mode=P size=505x512 at 0x6084EF0>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=96x96 at 0x607B830>]

# %%
for item in io:
    b = item.resize((100,100))
    ir.append(b)
    item.show()

# %%
for rimg in ir:
    rimg.show()

# %%
b
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x607B2B0>

# %%
ir
# Out:
# [<PIL.Image.Image image mode=P size=100x100 at 0x6084DB0>,
#  <PIL.Image.Image image mode=P size=100x100 at 0x6084E70>,
#  <PIL.Image.Image image mode=RGBA size=100x100 at 0x60849B0>,
#  <PIL.Image.Image image mode=P size=100x100 at 0x607B3F0>,
#  <PIL.Image.Image image mode=P size=100x100 at 0x607B6B0>,
#  <PIL.Image.Image image mode=P size=100x100 at 0x6084870>,
#  <PIL.Image.Image image mode=RGBA size=100x100 at 0x607B2B0>]
