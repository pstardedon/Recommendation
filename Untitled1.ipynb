# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import glob

# %%
path ='sp.jpg'
path1 = 'pre.jpg'

# %%
s = Image.open(path1)
s
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1316x768 at 0xF51F70>

# %%
img = plt.imread(path)
plt.imshow(img)
plt.show()

img1 = plt.imread(path1)
plt.imshow(img1)
plt.show()

# %%
x = np.asarray(img)
y = np.asarray(img1)

# %%
x
# Out:
# array([[[21, 28, 46],
#         [13, 22, 39],
#         [14, 26, 42],
#         ...,
#         [11, 11, 11],
#         [ 9,  9,  9],
#         [18, 18, 18]],
#
#        [[12, 21, 38],
#         [ 3, 12, 29],
#         [ 4, 13, 30],
#         ...,
#         [ 1,  1,  1],
#         [ 0,  0,  0],
#         [ 8,  8,  8]],
#
#        [[15, 24, 41],
#         [ 4, 13, 30],
#         [ 5, 14, 31],
#         ...,
#         [ 1,  1,  1],
#         [ 0,  0,  0],
#         [10, 10, 10]],
#
#        ...,
#
#        [[14, 23, 38],
#         [ 6, 15, 30],
#         [ 6, 15, 30],
#         ...,
#         [ 7, 23, 39],
#         [ 6, 22, 38],
#         [14, 31, 47]],
#
#        [[14, 23, 38],
#         [ 5, 14, 29],
#         [ 6, 15, 30],
#         ...,
#         [ 7, 23, 39],
#         [ 6, 22, 38],
#         [14, 31, 47]],
#
#        [[16, 25, 40],
#         [ 7, 16, 31],
#         [ 7, 16, 31],
#         ...,
#         [ 7, 23, 39],
#         [ 6, 22, 38],
#         [13, 30, 46]]], dtype=uint8)

# %%
x.shape
# Out:
# (2160, 3840, 3)

# %%
y.shape
# Out:
# (768, 1316, 3)

# %%
img
# Out:
# array([[[21, 28, 46],
#         [13, 22, 39],
#         [14, 26, 42],
#         ...,
#         [11, 11, 11],
#         [ 9,  9,  9],
#         [18, 18, 18]],
#
#        [[12, 21, 38],
#         [ 3, 12, 29],
#         [ 4, 13, 30],
#         ...,
#         [ 1,  1,  1],
#         [ 0,  0,  0],
#         [ 8,  8,  8]],
#
#        [[15, 24, 41],
#         [ 4, 13, 30],
#         [ 5, 14, 31],
#         ...,
#         [ 1,  1,  1],
#         [ 0,  0,  0],
#         [10, 10, 10]],
#
#        ...,
#
#        [[14, 23, 38],
#         [ 6, 15, 30],
#         [ 6, 15, 30],
#         ...,
#         [ 7, 23, 39],
#         [ 6, 22, 38],
#         [14, 31, 47]],
#
#        [[14, 23, 38],
#         [ 5, 14, 29],
#         [ 6, 15, 30],
#         ...,
#         [ 7, 23, 39],
#         [ 6, 22, 38],
#         [14, 31, 47]],
#
#        [[16, 25, 40],
#         [ 7, 16, 31],
#         [ 7, 16, 31],
#         ...,
#         [ 7, 23, 39],
#         [ 6, 22, 38],
#         [13, 30, 46]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
type(s)
# Out:
# PIL.JpegImagePlugin.JpegImageFile
