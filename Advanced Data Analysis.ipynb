# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
# %matplotlib inline

# %%
dir= '\\Users\\PRECIOUS\\Documents\\pratice'

# %%
os.chdir(dir)

# %%
folder=  [file for file in os.listdir('.\\Sales_Data')]

# %%
folder
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
nd= pd.DataFrame()

# %%
for files in folder:
    df= pd.read_csv('.\\Sales_Data\\'+ files)
    nd= pd.concat([df, nd])

# %%
nd
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
z = []
for items in glob.glob('Sales_Data\\*.csv'):
    print(items)
    z.append(items)
# Out:
# Sales_Data\Sales_April_2019.csv
# Sales_Data\Sales_August_2019.csv
# Sales_Data\Sales_December_2019.csv
# Sales_Data\Sales_February_2019.csv
# Sales_Data\Sales_January_2019.csv
# Sales_Data\Sales_July_2019.csv
# Sales_Data\Sales_June_2019.csv
# Sales_Data\Sales_March_2019.csv
# Sales_Data\Sales_May_2019.csv
# Sales_Data\Sales_November_2019.csv
# Sales_Data\Sales_October_2019.csv
# Sales_Data\Sales_September_2019.csv

# %%
z
# Out:
# ['Sales_Data\\Sales_April_2019.csv',
#  'Sales_Data\\Sales_August_2019.csv',
#  'Sales_Data\\Sales_December_2019.csv',
#  'Sales_Data\\Sales_February_2019.csv',
#  'Sales_Data\\Sales_January_2019.csv',
#  'Sales_Data\\Sales_July_2019.csv',
#  'Sales_Data\\Sales_June_2019.csv',
#  'Sales_Data\\Sales_March_2019.csv',
#  'Sales_Data\\Sales_May_2019.csv',
#  'Sales_Data\\Sales_November_2019.csv',
#  'Sales_Data\\Sales_October_2019.csv',
#  'Sales_Data\\Sales_September_2019.csv']

# %%
data = pd.DataFrame()

# %%
for nfiles in z:
    dft = pd.read_csv(nfiles)
    data = pd.concat([dft,data])

# %%
data
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
nd
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
nd.dropna(inplace= True)

# %%
nd
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001
# ...

# %%
nd['Month']= nd['Order Date'].str[0:2]

# %%
# nd['Month'] = pd.to_numeric(nd['Month'])

# %%
cdata= nd.query('Month != "Or"')
cdata
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address Month
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001    09
# ...

# %%
nd['Order Date'].str[0:2]
# Out:
# 0        09
# 1        09
# 2        09
# 3        09
# 4        09
#          ..
# 18378    04
# 18379    04
# 18380    04
# 18381    04
# 18382    04
# Name: Order Date, Length: 186305, dtype: object

# %%
nd['Order Date'].str[0:2]== 'Or'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18378    False
# 18379    False
# 18380    False
# 18381    False
# 18382    False
# Name: Order Date, Length: 186305, dtype: bool

# %%
nd[nd['Order Date'].str[0:2]== 'Or']
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1679   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3732   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3790   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4323   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5579   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 15280  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17208  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17324  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17339  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17744  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address Month
# 1679   Purchase Address    Or
# 3732   Purchase Address    Or
# 3790   Purchase Address    Or
# 4323   Purchase Address    Or
# ...

# %%
nd[nd['Order Date'].str[0:2]!= 'Or']
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address Month
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001    09
# ...

# %%
qd= nd.query('Month != "Or"')
qd
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       248151     AA Batteries (4-pack)                4       3.84
# 1       248152      USB-C Charging Cable                2      11.95
# 2       248153      USB-C Charging Cable                1      11.95
# 3       248154          27in FHD Monitor                1     149.99
# 4       248155      USB-C Charging Cable                1      11.95
# ...        ...                       ...              ...        ...
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address Month
# 0      09/17/19 14:44     380 North St, Los Angeles, CA 90001    09
# ...

# %%
qd['Month'] = pd.to_numeric(qd['Month'])
qd['Quantity Ordered'] = pd.to_numeric(qd['Quantity Ordered'])
qd['Price Each'] = pd.to_numeric(qd['Price Each'])
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
qd['Total Sales'] = qd['Quantity Ordered']*qd['Price Each']
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
qd
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       248151     AA Batteries (4-pack)                 4        3.84
# 1       248152      USB-C Charging Cable                 2       11.95
# 2       248153      USB-C Charging Cable                 1       11.95
# 3       248154          27in FHD Monitor                 1      149.99
# 4       248155      USB-C Charging Cable                 1       11.95
# ...        ...                       ...               ...         ...
# 18378   194090              Google Phone                 1      600.00
# 18379   194091     AA Batteries (4-pack)                 1        3.84
# 18380   194092    AAA Batteries (4-pack)                 2        2.99
# 18381   194093     AA Batteries (4-pack)                 1        3.84
# 18382   194094  Lightning Charging Cable                 1       14.95
#
#            Order Date                        Purchase Address  Month  \
# ...

# %%
grp = qd.groupby('Month')['Total Sales']

# %%
grp.count()
# Out:
# Month
# 1      9709
# 2     11975
# 3     15153
# 4     18279
# 5     16566
# 6     13554
# 7     14293
# 8     11961
# 9     11621
# 10    20282
# 11    17573
# 12    24984
# Name: Total Sales, dtype: int64

# %%
grp.sum()
# Out:
# Month
# 1     1.822257e+06
# 2     2.202022e+06
# 3     2.807100e+06
# 4     3.390670e+06
# 5     3.152607e+06
# 6     2.577802e+06
# 7     2.647776e+06
# 8     2.244468e+06
# 9     2.097560e+06
# 10    3.736727e+06
# 11    3.199603e+06
# 12    4.613443e+06
# Name: Total Sales, dtype: float64

# %%
y = grp.sum()

# %%
month= range(1,13)

# %%
plt.bar(month, y)
plt.xticks(month)
plt.show()

# %%
qd
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       248151     AA Batteries (4-pack)                 4        3.84
# 1       248152      USB-C Charging Cable                 2       11.95
# 2       248153      USB-C Charging Cable                 1       11.95
# 3       248154          27in FHD Monitor                 1      149.99
# 4       248155      USB-C Charging Cable                 1       11.95
# ...        ...                       ...               ...         ...
# 18378   194090              Google Phone                 1      600.00
# 18379   194091     AA Batteries (4-pack)                 1        3.84
# 18380   194092    AAA Batteries (4-pack)                 2        2.99
# 18381   194093     AA Batteries (4-pack)                 1        3.84
# 18382   194094  Lightning Charging Cable                 1       14.95
#
#            Order Date                        Purchase Address  Month  \
# ...

# %%
def getCity(address):
    return address.split(',')[1]
def getState(address):
    return address.split(',')[2].split(' ')[1]

# %%
qd['CIty']= qd['Purchase Address'].apply(lambda x: f'{getCity(x)} ({getState(x)})')
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
qd['Order Date'] = pd.to_datetime(qd['Order Date'])
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
qd['HR'] = qd['Order Date'].dt.hour
qd['MIN'] = qd['Order Date'].dt.minute
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
qd
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       248151     AA Batteries (4-pack)                 4        3.84
# 1       248152      USB-C Charging Cable                 2       11.95
# 2       248153      USB-C Charging Cable                 1       11.95
# 3       248154          27in FHD Monitor                 1      149.99
# 4       248155      USB-C Charging Cable                 1       11.95
# ...        ...                       ...               ...         ...
# 18378   194090              Google Phone                 1      600.00
# 18379   194091     AA Batteries (4-pack)                 1        3.84
# 18380   194092    AAA Batteries (4-pack)                 2        2.99
# 18381   194093     AA Batteries (4-pack)                 1        3.84
# 18382   194094  Lightning Charging Cable                 1       14.95
#
#                Order Date                        Purchase Address  Month  \
# ...

# %%
grphr = qd.groupby('HR')['Total Sales']
grpsum = qd.groupby('Total Sales')

# %%
grphr.sum()
# Out:
# HR
# 0      713721.27
# 1      460866.88
# 2      234851.44
# 3      145757.89
# 4      162661.01
# 5      230679.82
# 6      448113.00
# 7      744854.12
# 8     1192348.97
# 9     1639030.58
# 10    1944286.77
# 11    2300610.24
# 12    2316821.34
# 13    2155389.80
# 14    2083672.73
# 15    1941549.60
# 16    1904601.31
# 17    2129361.61
# 18    2219348.30
# 19    2412938.54
# 20    2281716.24
# 21    2042000.86
# 22    1607549.21
# 23    1179304.44
# Name: Total Sales, dtype: float64

# %%
time = range(0,24)
plt.bar(time, grphr.sum())
plt.xticks(time)
plt.show()

plt.plot(time, grphr.sum())
plt.xticks(time)
plt.grid()
plt.show()

# %%
sameData = qd[qd['Order ID'].duplicated(keep= False)]
sameData
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 20      248171        USB-C Charging Cable                 1       11.95
# 21      248171        USB-C Charging Cable                 1       11.95
# 60      248210                      iPhone                 1      700.00
# 61      248210    Lightning Charging Cable                 1       14.95
# 70      248219  Bose SoundSport Headphones                 1       99.99
# ...        ...                         ...               ...         ...
# 18336   194050        USB-C Charging Cable                 1       11.95
# 18342   194056                      iPhone                 1      700.00
# 18343   194056    Lightning Charging Cable                 1       14.95
# 18348   194061                      iPhone                 1      700.00
# 18349   194061    Lightning Charging Cable                 3       14.95
#
#            Order Date                            Purchase Address  Month  \
# ...

# %%
sameData['Same Products'] = sameData.groupby('Order ID')['Product'].transform(lambda x: ', '.join(x))
sameData
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 20      248171        USB-C Charging Cable                 1       11.95
# 21      248171        USB-C Charging Cable                 1       11.95
# 60      248210                      iPhone                 1      700.00
# 61      248210    Lightning Charging Cable                 1       14.95
# 70      248219  Bose SoundSport Headphones                 1       99.99
# ...        ...                         ...               ...         ...
# ...

# %%
selectedData = sameData[['Order ID', 'Same Products']]

# %%
selectedData
# Out:
#       Order ID                                Same Products
# 20      248171   USB-C Charging Cable, USB-C Charging Cable
# 21      248171   USB-C Charging Cable, USB-C Charging Cable
# 60      248210             iPhone, Lightning Charging Cable
# 61      248210             iPhone, Lightning Charging Cable
# 70      248219     Bose SoundSport Headphones, Google Phone
# ...        ...                                          ...
# 18336   194050  AA Batteries (4-pack), USB-C Charging Cable
# 18342   194056             iPhone, Lightning Charging Cable
# 18343   194056             iPhone, Lightning Charging Cable
# 18348   194061             iPhone, Lightning Charging Cable
# 18349   194061             iPhone, Lightning Charging Cable
#
# [14649 rows x 2 columns]

# %%
selectedData.drop_duplicates(inplace = True)
# Out:
# C:\Users\PRECIOUS\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
selectedData
# Out:
#       Order ID                                Same Products
# 20      248171   USB-C Charging Cable, USB-C Charging Cable
# 60      248210             iPhone, Lightning Charging Cable
# 70      248219     Bose SoundSport Headphones, Google Phone
# 117     248265  Vareebadd Phone, Bose SoundSport Headphones
# 176     248323     Google Phone, Bose SoundSport Headphones
# ...        ...                                          ...
# 18291   194008      AA Batteries (4-pack), Wired Headphones
# 18305   194021               Google Phone, Wired Headphones
# 18335   194050  AA Batteries (4-pack), USB-C Charging Cable
# 18342   194056             iPhone, Lightning Charging Cable
# 18348   194061             iPhone, Lightning Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

# %%
x = Counter()
for i in selectedData['Same Products']:
    rlist = i.split(',')
    x.update(Counter(combinations(rlist, 3)))

# %%
x.most_common(1)
# Out:
# [(('Google Phone', ' USB-C Charging Cable', ' Wired Headphones'), 87)]

# %%
i
# Out:
# 'iPhone, Lightning Charging Cable'

# %%
for f in selectedData['Same Products']:
    print(f)
# Out:
# USB-C Charging Cable, USB-C Charging Cable
# iPhone, Lightning Charging Cable
# Bose SoundSport Headphones, Google Phone
# Vareebadd Phone, Bose SoundSport Headphones
# Google Phone, Bose SoundSport Headphones
# Vareebadd Phone, Wired Headphones
# iPhone, Lightning Charging Cable, Apple Airpods Headphones
# Bose SoundSport Headphones, 34in Ultrawide Monitor
# iPhone, Lightning Charging Cable, Apple Airpods Headphones
# Apple Airpods Headphones, Lightning Charging Cable
# Google Phone, Bose SoundSport Headphones
# 27in 4K Gaming Monitor, AA Batteries (4-pack)
# iPhone, Apple Airpods Headphones
# Vareebadd Phone, USB-C Charging Cable
# Apple Airpods Headphones, Lightning Charging Cable
# Lightning Charging Cable, Bose SoundSport Headphones
# Lightning Charging Cable, AA Batteries (4-pack)
# AA Batteries (4-pack), AA Batteries (4-pack)
# Lightning Charging Cable, AA Batteries (4-pack)
# Lightning Charging Cable, 27in FHD Monitor
# Vareebadd Phone, USB-C Charging Cable
# ...

# %%
sameData.to_csv('SameData.csv')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PRECIOUS\\Documents\\pratice'
